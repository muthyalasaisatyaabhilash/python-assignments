# %% [markdown]
# 1.A) re.compile is responsible for gengerating regex objects
#
# 2.A) raw string won't be consider \ as an escape character
#
# 3.A) search function returns match objects it returns None if match is not found
#
# 4.A) we can use group() to get the actual strings that match the pattern.
#
# 5.A) group(0) returns entire match object.
# group(1) returns first word in the overall match object.
# group(2) returns second word in the overall match object.
#
# 6.A) by using backslash() we can tell a regex that you want it to fit real parentheses and periods
#
# 7.A) regex with no groups returns a list of strings,
# regex with groups returns list of tuples
#
# 8.A) in regular expression, | means either or
#
# 9.A) in regular expreesion , character is an regular character or meta character
#
# 10.A) '+' means one or more occurance of the regex preceding + symbol,
# '' means zero or more occurance of the regex preceding symbol
#
# 11.A) {4,5} braces match any repetitions preceding regex from 4 to 5 both inclusive.
# {4} braces match any repetition preceding regex 4 times.
#
# 12.A)
# \d signifies any decimal digit , set class[0-9]
# \w signifies alphanumeric, set class [a-zA-Z0-9]
# \s signifies whitespace
#
# 13.A)
# \D signifies any non digit, set class [^0-9]
# \W signifies any non alphanumeric, set class [a-zA-Z0-9]
# \S signifies non-whitespace
#
# 14.A)
# A=eeeAiiZuuuuAoooZeeee
# A. Z yields 1 match: AiiZuuuuAoooZ #-----greedy----
# A. ?Z yields 2 matches: AiiZ and AoooZ -------non-greedy-------
#
# 15.A)
#
# [a-z0-9] is the syntax for matching both numbers and lowercase letters with a character class
#
# 16.A)
#
# the procedure for making a normal expression in regax case insensitive is re.IGNORECASE
#
# 17.A)
# The . character in a regular expression will match any character except for a newline.
# By passing re.DOTALL as the second argument to re.compile(), you can make the dot character match all characters, including the newline character.
#
# 18.A)
# it replaces the decimal digit with X
# X drummers, X pipers, five rings, X hens
#
# 19.A)
# To ignore whitespace and comments in the regular expression.
#
# 20.A)
# a = re.compile(r'(^\d{1,3})(,\d{3})*$')
#
# 21.A)
# a = re.compile(r'[A-Z]\w [A-Z]\w')
#
# 22.A) a = re.compile(r'(Alice|Bob|Carol)\s(eats|pets|throws)\s(apples|cats|baseballs).', re.I|re.DOTALL)
